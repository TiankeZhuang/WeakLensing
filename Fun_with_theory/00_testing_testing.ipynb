# %%
from halotools.empirical_models import PrebuiltHodModelFactory
model_1 = PrebuiltHodModelFactory('zu_mandelbaum15')
model_2 = PrebuiltHodModelFactory('zheng07')

from halotools.sim_manager import FakeSim
fakesim = FakeSim()
# Out:
# /home/tzhuang/anaconda3/lib/python3.7/site-packages/halotools/empirical_models/factories/prebuilt_model_factory.py:258: UserWarning: This particular model is still being tested in collaboration with Ying Zu.
# If you need to use this prebuilt model for science,
# you will either need to test it yourself
# or wait for the Halotools developers to finish science verification.
#
#   warn(under_development_warning.format("Ying Zu"))

# %%
model_1.populate_mock(fakesim)
model_2.populate_mock(fakesim)

# %%
model_1.mock.galaxy_table
# Out:
# <Table length=74965>
#   conc_NFWmodel          halo_vy       ...         z
#      float64             float64       ...      float64
# ------------------ ------------------- ... ------------------
#  7.781632586635675  -69.03944754202604 ... 156.02794344615106
# 14.761519940814537 -414.04231477343325 ...  35.19536659535474
# 11.182221506533203  -65.68462411254484 ... 229.53879514481682
#  9.324838479088758  121.67317522445046 ...  221.5162626607796
# 11.529044949210387  -185.3693187687242 ... 215.28974131792435
# 13.678695767422214    76.2793378972998 ... 231.73748119927035
#  6.100895226854993   398.0745365647972 ... 247.18591255852886
# 12.554837827537895  -440.8643393247329 ... 131.30635005633397
#  6.115213080558878  -396.0607456146635 ... 180.86275589526664
# 13.271850684646816   242.7919864934039 ...   91.7803494478579
#                ...                 ... ...                ...
#   7.49757709266504  -261.9838883858903 ...  1.230274840715828
# ...

# %%
model_2.mock.galaxy_table
# Out:
# <Table length=83090>
#   conc_NFWmodel          halo_vy       ...         z
#      float64             float64       ...      float64
# ------------------ ------------------- ... ------------------
# 13.766617922066711  -43.98024285552407 ...  80.23573413271637
# 10.018917060795808 -101.84570288122438 ...  13.72111561078207
# 13.924847781966031  -175.8359597811595 ... 234.40227993792442
# 7.1271418049165565   391.0373942760033 ... 164.76016305627803
#  4.164399205734521 -105.36087582592978 ... 126.02197917473445
# 10.788108428647426  379.28278365963536 ...  47.43439432790239
#  7.073643627494739 -157.37538808162367 ... 103.68451796705335
#  4.801822382558079  126.62651962417567 ... 46.390781118532374
#  4.428499869422921   60.33356880383883 ... 204.15180445631952
# 12.100477211843547   446.5951061535633 ... 222.95898759333295
#                ...                 ... ...                ...
#   7.49757709266504  -261.9838883858903 ... 1.4168643194831703
# ...
